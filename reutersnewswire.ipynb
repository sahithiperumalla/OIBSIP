# %% [markdown]
# <a href="https://colab.research.google.com/github/sahithiperumalla/OIBSIP/blob/main/reutersnewswire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y)=reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical
def OneHotEncoding_fn(ReutersData, dimension=10000):
  OneHotEncoded_Data=np.zeros((len(ReutersData),dimension))
  for i, sequence in enumerate(ReutersData):
    OneHotEncoded_Data[i,sequence]=1
  return OneHotEncoded_Data
x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 86ms/step - loss: 2.6325 - categorical_accuracy: 0.4617 - val_loss: 1.7408 - val_categorical_accuracy: 0.6363
# Epoch 2/25
# 16/16 [==============================] - 1s 56ms/step - loss: 1.4985 - categorical_accuracy: 0.6814 - val_loss: 1.3119 - val_categorical_accuracy: 0.7113
# Epoch 3/25
# 16/16 [==============================] - 1s 54ms/step - loss: 1.1436 - categorical_accuracy: 0.7504 - val_loss: 1.1382 - val_categorical_accuracy: 0.7437
# Epoch 4/25
# 16/16 [==============================] - 1s 53ms/step - loss: 0.9324 - categorical_accuracy: 0.7961 - val_loss: 1.0437 - val_categorical_accuracy: 0.7750
# Epoch 5/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.7673 - categorical_accuracy: 0.8356 - val_loss: 0.9796 - val_categorical_accuracy: 0.7862
# Epoch 6/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.6437 - categorical_accuracy: 0.8620 - val_loss: 0.9330 - val_categorical_accuracy: 0.8087
# Epoch 7/25
# 16/16 [==============================] - 1s 57ms/step - loss: 0.5388 - categorical_accuracy: 0.8838 - val_loss: 0.9015 - val_categorical_accuracy: 0.8138
# Epoch 8/25
# 16/16 [==============================] - 1s 90ms/step - loss: 0.4528 - categorical_accuracy: 0.9052 - val_loss: 0.8816 - val_categorical_accuracy: 0.8138
# Epoch 9/25
# 16/16 [==============================] - 1s 87ms/step - loss: 0.3826 - categorical_accuracy: 0.9179 - val_loss: 0.8818 - val_categorical_accuracy: 0.8125
# Epoch 10/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.3245 - categorical_accuracy: 0.9320 - val_loss: 0.8555 - val_categorical_accuracy: 0.8238
# Epoch 11/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2890 - categorical_accuracy: 0.9350 - val_loss: 0.8675 - val_categorical_accuracy: 0.8250
# Epoch 12/25
# 16/16 [==============================] - 1s 43ms/step - loss: 0.2509 - categorical_accuracy: 0.9433 - val_loss: 0.8755 - val_categorical_accuracy: 0.8188
# Epoch 13/25
# 16/16 [==============================] - 1s 53ms/step - loss: 0.2211 - categorical_accuracy: 0.9470 - val_loss: 0.8911 - val_categorical_accuracy: 0.8188
# Epoch 14/25
# 16/16 [==============================] - 1s 54ms/step - loss: 0.2026 - categorical_accuracy: 0.9488 - val_loss: 0.8969 - val_categorical_accuracy: 0.8200
# Epoch 15/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1826 - categorical_accuracy: 0.9532 - val_loss: 0.9156 - val_categorical_accuracy: 0.8175
# Epoch 16/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1663 - categorical_accuracy: 0.9564 - val_loss: 0.9217 - val_categorical_accuracy: 0.8150
# Epoch 17/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1570 - categorical_accuracy: 0.9548 - val_loss: 0.9457 - val_categorical_accuracy: 0.8200
# Epoch 18/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1500 - categorical_accuracy: 0.9573 - val_loss: 0.9454 - val_categorical_accuracy: 0.8188
# Epoch 19/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1436 - categorical_accuracy: 0.9551 - val_loss: 0.9724 - val_categorical_accuracy: 0.8163
# Epoch 20/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1368 - categorical_accuracy: 0.9567 - val_loss: 0.9662 - val_categorical_accuracy: 0.8087
# Epoch 21/25
# 16/16 [==============================] - 1s 61ms/step - loss: 0.1277 - categorical_accuracy: 0.9583 - val_loss: 0.9674 - val_categorical_accuracy: 0.8150
# Epoch 22/25
# 16/16 [==============================] - 2s 120ms/step - loss: 0.1256 - categorical_accuracy: 0.9565 - val_loss: 0.9945 - val_categorical_accuracy: 0.8062
# Epoch 23/25
# 16/16 [==============================] - 2s 138ms/step - loss: 0.1242 - categorical_accuracy: 0.9555 - val_loss: 0.9951 - val_categorical_accuracy: 0.8138
# Epoch 24/25
# 16/16 [==============================] - 1s 55ms/step - loss: 0.1119 - categorical_accuracy: 0.9605 - val_loss: 1.0266 - val_categorical_accuracy: 0.8087
# Epoch 25/25
# 16/16 [==============================] - 1s 55ms/step - loss: 0.1158 - categorical_accuracy: 0.9594 - val_loss: 1.0418 - val_categorical_accuracy: 0.7962

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
